# %%
import tensorflow as tf
# Out:
# c:\Users\user\Desktop\aiml\Daily-Practice\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\desktop\aiml\daily-practice\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation= 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# c:\Users\user\Desktop\aiml\Daily-Practice\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9144 - loss: 0.2944
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9577 - loss: 0.1438
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9679 - loss: 0.1059
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9740 - loss: 0.0862
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9761 - loss: 0.0765
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9751 - loss: 0.0822
# [0.08218330889940262, 0.9750999808311462]

# %%
pip freeze > requirements2.txt # list of packages given
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt # to install evertything from txt file
# Out:
# Collecting absl-py==2.3.1 (from -r requirements.txt (line 1))
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: asttokens==3.0.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 2)) (3.0.1)
# Collecting astunparse==1.6.3 (from -r requirements.txt (line 3))
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting certifi==2025.11.12 (from -r requirements.txt (line 4))
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting charset-normalizer==3.4.4 (from -r requirements.txt (line 5))
#   Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: colorama==0.4.6 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 7)) (0.2.3)
# Collecting debugpy==1.8.19 (from -r requirements.txt (line 8))
#   Using cached debugpy-1.8.19-cp314-cp314-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: decorator==5.2.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: executing==2.2.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 10)) (2.2.1)
# Collecting flatbuffers==25.12.19 (from -r requirements.txt (line 11))
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast==0.7.0 (from -r requirements.txt (line 12))
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta==0.2.0 (from -r requirements.txt (line 13))
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting grpcio==1.76.0 (from -r requirements.txt (line 14))
#   Downloading grpcio-1.76.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting h5py==3.15.1 (from -r requirements.txt (line 15))
#   Downloading h5py-3.15.1-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# Collecting idna==3.11 (from -r requirements.txt (line 16))
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: ipykernel==7.1.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: ipython==9.8.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from -r requirements.txt (line 18)) (9.8.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 19)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 20)) (0.19.2)
# Collecting jupyter_client==8.7.0 (from -r requirements.txt (line 21))
#   Using cached jupyter_client-8.7.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.9.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 22)) (5.9.1)
# Collecting keras==3.13.0 (from -r requirements.txt (line 23))
#   Downloading keras-3.13.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting libclang==18.1.1 (from -r requirements.txt (line 24))
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting Markdown==3.10 (from -r requirements.txt (line 25))
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py==4.0.0 (from -r requirements.txt (line 26))
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: MarkupSafe==3.0.3 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from -r requirements.txt (line 27)) (3.0.3)
# Requirement already satisfied: matplotlib-inline==0.2.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 28)) (0.2.1)
# Collecting mdurl==0.1.2 (from -r requirements.txt (line 29))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting ml_dtypes==0.5.4 (from -r requirements.txt (line 30))
#   Downloading ml_dtypes-0.5.4-cp314-cp314-win_amd64.whl.metadata (9.2 kB)
# Collecting namex==0.1.0 (from -r requirements.txt (line 31))
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 32)) (1.6.0)
# Collecting numpy==2.4.0 (from -r requirements.txt (line 33))
#   Downloading numpy-2.4.0-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting opt_einsum==3.4.0 (from -r requirements.txt (line 34))
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting optree==0.18.0 (from -r requirements.txt (line 35))
#   Downloading optree-0.18.0-cp314-cp314-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: packaging==25.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 36)) (25.0)
# Requirement already satisfied: parso==0.8.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 37)) (0.8.5)
# Requirement already satisfied: pillow==12.0.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from -r requirements.txt (line 38)) (12.0.0)
# Collecting platformdirs==4.5.1 (from -r requirements.txt (line 39))
#   Using cached platformdirs-4.5.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prompt_toolkit==3.0.52 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 40)) (3.0.52)
# Collecting protobuf==6.33.2 (from -r requirements.txt (line 41))
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting psutil==7.2.1 (from -r requirements.txt (line 42))
#   Using cached psutil-7.2.1-cp37-abi3-win_amd64.whl.metadata (23 kB)
# Requirement already satisfied: pure_eval==0.2.3 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 43)) (0.2.3)
# Requirement already satisfied: Pygments==2.19.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 44)) (2.19.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 45)) (2.9.0.post0)
# Requirement already satisfied: pyzmq==27.1.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 46)) (27.1.0)
# Collecting requests==2.32.5 (from -r requirements.txt (line 47))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting rich==14.2.0 (from -r requirements.txt (line 48))
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: setuptools==80.9.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from -r requirements.txt (line 49)) (80.9.0)
# Requirement already satisfied: six==1.17.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 50)) (1.17.0)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\user\appdata\roaming\python\python314\site-packages (from -r requirements.txt (line 51)) (0.6.3)
# Collecting tensorboard==2.20.0 (from -r requirements.txt (line 52))
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboard-data-server==0.7.2 (from -r requirements.txt (line 53))
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.26.0 Requires-Python >=3.9,<3.13; 1.26.1 Requires-Python >=3.9,<3.13
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.20.0 (from versions: none)
# ERROR: No matching distribution found for tensorflow==2.20.0

# %%
import sklearn

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_loss, test_accuracy = model.evaluate(x_test, y_test)
#       2 print(f"Test Loss: {test_loss}")
#       3 print(f"Test Accuracy: {test_accuracy}")
#
# NameError: name 'model' is not defined
