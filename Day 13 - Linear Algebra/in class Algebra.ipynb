# %% [markdown]
# -data -
#
# - iris: [sepal length]
# - titanic: [pclass,sibsp]

# %% [markdown]
# Columns = vectors

# %%
vector1 = [30,4,10]
vector2 = [20,4,10]
vector3 = [30,4,10]
type(vector1)
# Out:
# list

# %%
matrix = [vector1,vector2]

# %%
list2 = [3,4,5,'idrees',4.5,[3,['a','b'],5]]
list2[5][1][0]
# Out:
# 'a'

# %%
import numpy as np

arr = np.array(vector1)

type(arr)
arr.mean()
arr.max()
# Out:
# np.int64(30)

# %%
vector1 = [30,4,10]
vector2 = [20,4,10]
vector3 = [30,4,10]

matrix = [[30,4,10],
          [20,4,10],
          [30,4,10]
    
]
matrix[0][1]
# Out:
# 4

# %%
matrix = [[30,4,10],
          [20,4,10],
          [30,4,10]
    
]

matrixarr = np.array(matrix)
type(matrixarr)
# Out:
# numpy.ndarray

# %%
matrixarr.ndim
# Out:
# 2

# %%
#2Dimensional is when we have rows and columns

# %%
matrixarr[1][1]
# Out:
# np.int64(4)

# %%
matrixarr[1:2][0] # 0 tu sebb before dah jadi new matrix so start dari 0 balik
# Out:
# array([20,  4, 10])

# %%
matrixarr * 2 # scalar multiplication # broadcastinggggggggggg

# scalar pperations with arrays 

matrixarr * 2
# Out:
# array([[60,  8, 20],
#        [40,  8, 20],
#        [60,  8, 20]])

# %%
matrixarr.shape # rows x columns
# Out:
# (3, 3)

# %%
matrixarr + 10
# Out:
# array([[40, 14, 20],
#        [30, 14, 20],
#        [40, 14, 20]])

# %%
a = np.array([1,3,5])
b = np.array([10,10,10]) # nak broadcast shape mesti sama

a+b
# Out:
# array([11, 13, 15])

# %%
a = np.array([[1,3,5,6],
             [2,8,7,9]]
             )
b = np.array([10,10,10,10]) # shape at least one mesti sama

print (a + b)
print (a - b)
print (a * b)
# Out:
# [[11 13 15 16]
#  [12 18 17 19]]
# [[-9 -7 -5 -4]
#  [-8 -2 -3 -1]]
# [[10 30 50 60]
#  [20 80 70 90]]

# %%
a.shape
# Out:
# (2, 4)

# %%
b.shape
# Out:
# (4,)

# %%
a1 = np.array([[1,3,5,6],
             [2,8,7,9]]
             )
b2 = np.array([[10],
             [100]])

print (a1 + b2)
print (a1 - b2)
print (a1 * b2)
# Out:
# [[ 11  13  15  16]
#  [102 108 107 109]]
# [[ -9  -7  -5  -4]
#  [-98 -92 -93 -91]]
# [[ 10  30  50  60]
#  [200 800 700 900]]

# %%
variance = np.array([454545,65645,745454,7676767])

n = np.array([145,445,656,768])

((variance)**0.5).round()
# Out:
# array([ 674.,  256.,  863., 2771.])

# %%
covariance = np.array([454545,656455])

n = np.array([145,445,656,768])

stdx , stdy = np.array([ 674.,  256.7])
stdx
stdy

r = covariance/(stdx*stdy)
r
# Out:
# array([2.62718781, 3.79419105])

# %%
x = np.array([[1,4,1],
              [2,5,2]]
              )

w = np.array([10,10,10])

matmultiply_xw = np.dot(x,w)
matmultiply_xw
# Out:
# array([60, 90])

# %%
w2 = np.array([[10,2,3],[10,2,3],[10,2,3]])
matmultiply_xw2 = np.dot(x,w2)
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])

# %%
matmultiply_xw2 = x @ w2 # better way 
matmultiply_xw2
# Out:
# array([[60, 12, 18],
#        [90, 18, 27]])
