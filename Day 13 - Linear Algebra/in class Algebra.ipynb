# %% [markdown]
# -data - all columns are vectors
#
# - iris: [sepal length]
# - titanic: [pclass,sibsp]

# %% [markdown]
# Columns = vectors

# %%
vector1 = [30,4,10]
vector2 = [20,4,10]
vector3 = [30,4,10]
type(vector1)

# %%
matrix = [vector1,vector2]

# %%
list2 = [3,4,5,'idrees',4.5,[3,['a','b'],5]]
list2[5][1][0]

# %%
import numpy as np

arr = np.array(vector1)

type(arr)
arr.mean()
arr.max()

# %%
vector1 = [30,4,10]
vector2 = [20,4,10]
vector3 = [30,4,10]

matrix = [[30,4,10],
          [20,4,10],
          [30,4,10]
    
]
matrix[0][1]

# %%
matrix = [[30,4,10],
          [20,4,10],
          [30,4,10]
    
]

matrixarr = np.array(matrix)
type(matrixarr)

# %%
matrixarr.ndim

# %%
#2Dimensional is when we have rows and columns

# %%
matrixarr[1][1]

# %%
matrixarr[1:2][0] # 0 tu sebb before dah jadi new matrix so start dari 0 balik

# %%
matrixarr * 2 # scalar multiplication # broadcastinggggggggggg

# scalar pperations with arrays 

matrixarr * 2

# %%
matrixarr.shape # rows x columns

# %%
matrixarr + 10

# %%
a = np.array([1,3,5])
b = np.array([10,10,10]) # nak broadcast shape mesti sama

a+b

# %%
a = np.array([[1,3,5,6],
             [2,8,7,9]]
             )
b = np.array([10,10,10,10]) # shape at least one mesti sama

print (a + b)
print (a - b)
print (a * b)

# %%
a.shape

# %%
b.shape

# %%
a1 = np.array([[1,3,5,6],
             [2,8,7,9]]
             )
b2 = np.array([[10],
             [100]])

print (a1 + b2)
print (a1 - b2)
print (a1 * b2)

# %%
variance = np.array([454545,65645,745454,7676767])

n = np.array([145,445,656,768])

((variance)**0.5).round()

# %%
covariance = np.array([454545,656455])

n = np.array([145,445,656,768])

stdx , stdy = np.array([ 674.,  256.7])
stdx
stdy

r = covariance/(stdx*stdy)
r

# %%
x = np.array([[1,4,1],
              [2,5,2]]
              )

w = np.array([10,10,10])

matmultiply_xw = np.dot(x,w)
matmultiply_xw

# %%
w2 = np.array([[10,2,3],[10,2,3],[10,2,3]])
matmultiply_xw2 = np.dot(x,w2)
matmultiply_xw2

# %%
matmultiply_xw2 = x @ w2 # better way matmul
matmultiply_xw2

# %%
import numpy as np
hetero = np.array([1,2,'2222','idrees',5.4])
#blh store different type tapi putput data type jadi numner
# Out:
# numpy.ndarray

# %%
hetero2 = np.array([1,2,4,8,5.4])
hetero.dtype
# Out:
# dtype('float64')

# %%
hetero = np.array(['idrees','ibrahim'])
hetero.dtype
# Out:
# dtype('<U7')

# %%
hetero[0]
# Out:
# np.str_('idrees')

# %%
A= np.array(
    [
        [2,3,4],
        [6,7,8],
        [3,2,3]
    ]
)

B = np.array(
    [[5,5,5],
    [2,2,2]]
)

B@A
# Out:
# array([[55, 60, 75],
#        [22, 24, 30]])

# %%
A = np.array([
    [5,5,5],
    [2,2,2],
    [5,5,5]
])

B = np.array([
    [3,3,3],
    [3,3,3],
    [3,3,3]
])

A@B
# Out:
# array([[45, 45, 45],
#        [18, 18, 18],
#        [45, 45, 45]])
