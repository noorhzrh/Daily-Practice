# %% [markdown]
# Metrics to use for testing performance of a classifier
#
# - I want you people to assess, and ask questions related to the ML process so far.
#
# - complicated or tough
#
# question 1; if we use seaborn, we can only assign target/input manually right?
#
# for linear regression, the input can be categorical/numerical
# for logistic, can categorical input be used
#
# - if we use one hot encoding how do we perform the model
#
# Classification Metrics:
#
# - Accuracy = all the time, not that usable - imbalance, it will not show you true performance
# - Precision = when FP are crucial = TP/TP + FP
# - Recall = when FN are crucial = TP/TP+FN
# - F1 Score = to check performance in general
