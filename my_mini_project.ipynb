# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

import plotly.express as px

# %%
crimedf = pd.read_csv("C:\\Users\\user\\Desktop\\aiml\\Daily-Practice\\Day 9 - Practice Data Analysis\\crime_district.csv")
crimedf.head()
# Out:
#       state district category type        date  crimes
# 0  Malaysia      All  assault  all  2016-01-01   22327
# 1  Malaysia      All  assault  all  2017-01-01   21366
# 2  Malaysia      All  assault  all  2018-01-01   16902
# 3  Malaysia      All  assault  all  2019-01-01   16489
# 4  Malaysia      All  assault  all  2020-01-01   13279

# %%
# to drop the first row from dataset which are the results of everything
# drop_malaysia = crimedf[crimedf['state'] == 'Malaysia'].index
# crimedf.drop(drop_malaysia, inplace=True)

# %%
# to drop the index and starts with 0
# crimedf.reset_index(drop=True,inplace=True)
# crimedf

# %%
#change data type of date from string
crimedf['date'] = pd.to_datetime(crimedf['date'])
#extract the year
crimedf['date'] = crimedf['date'].dt.year
crimedf['date'] = crimedf['date'].astype(int)

# %%
crimedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19152 entries, 0 to 19151
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     19152 non-null  object
#  1   district  19152 non-null  object
#  2   category  19152 non-null  object
#  3   type      19152 non-null  object
#  4   date      19152 non-null  int64
#  5   crimes    19152 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 897.9+ KB

# %%
# filter Malaysia and years 2016–2023
malaysia_df = crimedf[
    (crimedf['state'] == 'Malaysia') &
    (crimedf['district'] == 'All') &
    (crimedf['date'].between(2016, 2023)) &
    (crimedf['category'].isin(['assault', 'property']))
]

malaysia_df.head(50)
# Out:
#        state district category                  type  date  crimes
# 0   Malaysia      All  assault                   all  2016   22327
# 1   Malaysia      All  assault                   all  2017   21366
# 2   Malaysia      All  assault                   all  2018   16902
# 3   Malaysia      All  assault                   all  2019   16489
# 4   Malaysia      All  assault                   all  2020   13279
# 5   Malaysia      All  assault                   all  2021   11495
# 6   Malaysia      All  assault                   all  2022   10348
# 7   Malaysia      All  assault                   all  2023   10453
# 8   Malaysia      All  assault        causing_injury  2016    5531
# 9   Malaysia      All  assault        causing_injury  2017    5024
# 10  Malaysia      All  assault        causing_injury  2018    4660
# 11  Malaysia      All  assault        causing_injury  2019    4712
# 12  Malaysia      All  assault        causing_injury  2020    4118
# ...

# %%
crime_countsdf = (malaysia_df.groupby(['category','date'])['crimes'].sum().reset_index())
crime_countsdf
# crimes are groupby date and category
# Out:
#     category  date  crimes
# 0    assault  2016   44654
# 1    assault  2017   42732
# 2    assault  2018   33804
# 3    assault  2019   32978
# 4    assault  2020   26558
# 5    assault  2021   22990
# 6    assault  2022   20696
# 7    assault  2023   20906
# 8   property  2016  180056
# 9   property  2017  155608
# 10  property  2018  143520
# 11  property  2019  133934
# 12  property  2020  104688
# 13  property  2021   82958
# 14  property  2022   80930
# 15  property  2023   83982

# %%
bargraph = px.bar(crime_countsdf, x='date', y='crimes', color='category', title='Crime Counts in Malaysia (2016–2023): Assault vs Property')    # barmode='group'
# pakai crime_countsdf, 
bargraph.show()

# %%
malaysia_df
# Out:
#         state district  category                      type  date  crimes
# 0    Malaysia      All   assault                       all  2016   22327
# 1    Malaysia      All   assault                       all  2017   21366
# 2    Malaysia      All   assault                       all  2018   16902
# 3    Malaysia      All   assault                       all  2019   16489
# 4    Malaysia      All   assault                       all  2020   13279
# ..        ...      ...       ...                       ...   ...     ...
# 107  Malaysia      All  property  theft_vehicle_motorcycle  2019   22501
# 108  Malaysia      All  property  theft_vehicle_motorcycle  2020   16059
# 109  Malaysia      All  property  theft_vehicle_motorcycle  2021    9944
# 110  Malaysia      All  property  theft_vehicle_motorcycle  2022   10457
# 111  Malaysia      All  property  theft_vehicle_motorcycle  2023   10588
#
# [112 rows x 6 columns]

# %%
bystate_df = crimedf[
    (crimedf['district'] != 'All') &
    (crimedf['state'] != 'Malaysia') &
    (crimedf['type'] != 'all') &
    (crimedf['category'].isin(['assault','property']))
]

bystate_df
# Out:
#                    state     district  category                      type  \
# 232                Johor   Batu Pahat   assault            causing_injury
# 233                Johor   Batu Pahat   assault            causing_injury
# 234                Johor   Batu Pahat   assault            causing_injury
# 235                Johor   Batu Pahat   assault            causing_injury
# 236                Johor   Batu Pahat   assault            causing_injury
# ...                  ...          ...       ...                       ...
# 19147  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19148  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19149  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19150  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
# 19151  W.P. Kuala Lumpur  Wangsa Maju  property  theft_vehicle_motorcycle
#
#        date  crimes
# 232    2016      39
# 233    2017      41
# ...

# %%
crimebystate_countsdf = (bystate_df.groupby(['state'])['crimes'].sum().reset_index())
crimebystate_countsdf
# Out:
#                 state  crimes
# 0               Johor   65963
# 1               Kedah   43185
# 2            Kelantan   25348
# 3              Melaka   17980
# 4     Negeri Sembilan   23392
# 5              Pahang   22385
# 6               Perak   34352
# 7              Perlis    4019
# 8        Pulau Pinang   36653
# 9               Sabah   38944
# 10            Sarawak   43136
# 11           Selangor  157455
# 12         Terengganu   14984
# 13  W.P. Kuala Lumpur   77701

# %%
fig = px.bar(
    crimebystate_countsdf, x='state', y='crimes', color='state', title='Crime Counts in Malaysia (2016–2023) by states')    # barmode='group'
fig.show()

# %%
crimebystate_countsdf
# Out:
#                 state  crimes
# 0               Johor   65963
# 1               Kedah   43185
# 2            Kelantan   25348
# 3              Melaka   17980
# 4     Negeri Sembilan   23392
# 5              Pahang   22385
# 6               Perak   34352
# 7              Perlis    4019
# 8        Pulau Pinang   36653
# 9               Sabah   38944
# 10            Sarawak   43136
# 11           Selangor  157455
# 12         Terengganu   14984
# 13  W.P. Kuala Lumpur   77701

# %%
fig = px.imshow(crimebystate_countsdf)
fig.show()

# %%
sns.lineplot(malaysia_df,x='date',y='crimes')
sns.set(style='darkgrid')

# %%
sns.jointplot(malaysia_df, x='date' , y='crimes')

# %%
sns.boxenplot(malaysia_df,x='state',y='crimes')
sns.set(style='darkgrid')

#rc parameters
# runtime configurations
plt.rcParams["figure.figsize"]= (100, 60)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.linestyle'] = '--'

# %%
#rc parameters
plt.rcParams["figure.figsize"]= (10, 6)

# %%
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.scatter()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# need to set global context!! use import matplot

# %%
sns.set_theme(
    style='whitegrid',
    context='talk',
    rc={
        'figure.figsize':(8,4),
        'figure.dpi':120, # define pixel density resolution (density per ??)
        'axes.titlesize':12,
        'axes.labelsize': 10,
        'lines.linewidth':2,
        'lines.linestyle' :'--',
    }
)

# %%
sns.histplot(crimedf,x='state')
sns.set_theme(
    style='whitegrid',
    context='talk',
    rc={
        'figure.figsize':(8,4),
        'figure.dpi':120, # define pixel density resolution (density per ??)
        'axes.titlesize':12,
        'axes.labelsize': 10,
        'lines.linewidth':2,
        'lines.linestyle' :'--',
    }
)

# %%
#plotly 
mean = crimedf['crimes'].mean()
px.bar(crimedf, x='state', y=)
