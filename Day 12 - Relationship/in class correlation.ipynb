# %% [markdown]
# # import a data set of your choice from seaborn
# # create a barplot,make it 3D
# # Create a scatterplot
# # Create a pairplot

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
x = df['species'].unique()
y = df['species'].value_counts()
sns.barplot(x = x, y=y, hue=x)
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(data = df,x = 'species', y='bill_length_mm')
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
sns.pairplot(data=df, hue='species')

# %%
sns.scatterplot(data=df, x='bill_length_mm', y='bill_depth_mm',hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sdf= df.groupby('species')['body_mass_g'].mean()
sdf
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
df['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['bill_length_mm'], df['body_mass_g']) # plt.scatter (df['column name],df['column name])

# %%
df2 = df['species'].value_counts()
print(df2)
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df2.index
# Out:
# Index(['Adelie', 'Gentoo', 'Chinstrap'], dtype='object', name='species')

# %%
df2.value_counts()
# Out:
# count
# 152    1
# 124    1
# 68     1
# Name: count, dtype: int64

# %%
plt.bar(df2.index, df2)
# Out:
# <BarContainer object of 3 artists>
