# %%
import seaborn as sns

import pandas as pd

import matplotlib.pyplot as plt


from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.metrics import classification_report

# %%
tipsdf = sns.load_dataset('tips')
tipsdf.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
smoker_bin = pd.factorize(tipsdf['smoker'])
tipsdf['smoker_bin'] = smoker_bin[0]
tipsdf.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  smoker_bin
# 0       16.99  1.01  Female     No  Sun  Dinner     2           0
# 1       10.34  1.66    Male     No  Sun  Dinner     3           0

# %%
X = tipsdf[['total_bill']]
y = tipsdf['smoker_bin']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

model_dt = DecisionTreeClassifier()

model_dt.fit(X_train, y_train)

y_pred_dt = model_dt.predict(X_test)

cr_dt = classification_report(y_test,y_pred_dt)

print(cr_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        39
#            1       0.45      0.41      0.43        22
#
#     accuracy                           0.61        61
#    macro avg       0.57      0.56      0.56        61
# weighted avg       0.60      0.61      0.60        61

# %%
plt.figure(figsize=(12,8))

plot_tree(model_dt,
          feature_names= tipsdf['total_bill'], # input feature
          class_names= tipsdf['smoker'], # target feat
          max_depth=2,
          filled=True,
          rounded=True)

plt.show()

# %% [markdown]
# ### Random Forest
#
# - Ensemble method
# #Bagging    - combine the efforts of a lot of models

# %%
#bagging
model_rf = RandomForestClassifier(n_estimators=100)

model_rf.fit(X_train, y_train)

y_pred_rf = model_rf.predict(X_test)

# %%
cr_rf = classification_report(y_test,y_pred_rf)

print(cr_rf)

cr_dr = classification_report(y_test,y_pred_dt)

print(cr_dr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.49      0.53        39
#            1       0.29      0.36      0.32        22
#
#     accuracy                           0.44        61
#    macro avg       0.43      0.43      0.42        61
# weighted avg       0.47      0.44      0.45        61
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.54      0.57        39
#            1       0.31      0.36      0.33        22
#
#     accuracy                           0.48        61
#    macro avg       0.45      0.45      0.45        61
# weighted avg       0.49      0.48      0.48        61

# %%
model_ada = AdaBoostClassifier(n_estimators=100)

model_ada.fit(X_train, y_train)

y_pred_ada = model_ada.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model_ada = AdaBoostClassifier(n_estimators=1000)
#       3 model_ada.fit(X_train, y_train)
#       5 y_pred_ada = model_ada.predict(X_test)
#
# NameError: name 'AdaBoostClassifier' is not defined

# %%
cr_ada = classification_report(y_test,y_pred_ada)
print('--------------------ada boost-------------------------\n')
print(cr_ada)

cr_rf = classification_report(y_test,y_pred_rf)
print('---------------------bagging--------------------------\n')
print(cr_rf)
# Out:
# --------------------ada boost-------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.87      0.74        39
#            1       0.38      0.14      0.20        22
#
#     accuracy                           0.61        61
#    macro avg       0.51      0.50      0.47        61
# weighted avg       0.55      0.61      0.54        61
#
# ---------------------bagging--------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.49      0.53        39
#            1       0.29      0.36      0.32        22
#
#     accuracy                           0.44        61
#    macro avg       0.43      0.43      0.42        61
# weighted avg       0.47      0.44      0.45        61
