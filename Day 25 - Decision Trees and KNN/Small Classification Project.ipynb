# %% [markdown]
# ### Project : Cancer Detection

# %% [markdown]
# - Implement the following algorithms, and find out which one works the best, to predict cancer
#
# - algorithms:
#     - Decision Tree
#     - Random Forest
#     - AdaBoost
#     - KNN
#
# - Try to change the parameters of the mdoels. Hyparameters: Things you can change for the models:
#
#     - Depth of tree
#     - numer of estimators
#     - number of neighbours
#
# - Find the best performance.
#
# (Optional: )
# - Make predictions on your own defined inputs, not just the X
# - Best performance will get applause!

# %%
from sklearn.datasets import load_breast_cancer

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier,plot_tree

from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report

# %%
cancer = load_breast_cancer()

# %%
cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
cancer.data
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]], shape=(569, 30))

# %%
# X = cancer.data[:,0:[0,1,3,4,5,10]] 
# X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, 1.326e+03, 8.474e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, 1.203e+03, 1.096e-01],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, 8.581e+02, 8.455e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, 1.265e+03, 1.178e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, 1.810e+02, 5.263e-02]],
#       shape=(569, 5))

# %%
X = cancer.data
y = cancer.target

X_train, X_test, y_train, y_test = train_test_split(X,y)

model_dt = DecisionTreeClassifier(max_depth=3)
model_rf = RandomForestClassifier(max_depth=3)
model_adaboost = AdaBoostClassifier(n_estimators=1000)
model_knn = KNeighborsClassifier(n_neighbors=3)

model_dt.fit(X_train,y_train)
model_rf.fit(X_train,y_train)
model_adaboost.fit(X_train,y_train)
model_knn.fit(X_train,y_train)

y_pred_dt = model_dt.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_adaboost = model_adaboost.predict(X_test)
y_pred_knn = model_knn.predict(X_test)

# %%
y_pred_dt = model_dt.predict([[1.442e+01, 1.977e+01, 9.448e+01, 6.425e+02, 9.752e-02, 1.141e-01,
        9.388e-02, 5.839e-02, 1.879e-01, 6.390e-02, 2.895e-01, 1.851e+00,
        2.376e+00, 2.685e+01, 8.005e-03, 2.895e-02, 3.321e-02, 1.424e-02,
        1.462e-02, 4.452e-03, 1.633e+01, 3.086e+01, 1.095e+02, 8.264e+02,
        1.431e-01, 3.026e-01, 3.194e-01, 1.565e-01, 2.718e-01, 9.353e-02]])
y_pred_dt
# Out:
# array([1])

# %%
cr_dt = classification_report(y_test,y_pred_dt)
print('---------------Decision Tree------------')
print(cr_dt)

cr_rf = classification_report(y_test,y_pred_rf)
print('---------------Random Forest------------')
print(cr_rf)

cr_adaboost = classification_report(y_test,y_pred_adaboost)
print('---------------AdaBoost------------')
print(cr_dt)

cr_knn = classification_report(y_test,y_pred_knn)
print('---------------KNN------------')
print(cr_knn)
# Out:
# ---------------Decision Tree------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        58
#            1       0.95      0.96      0.96        85
#
#     accuracy                           0.95       143
#    macro avg       0.95      0.95      0.95       143
# weighted avg       0.95      0.95      0.95       143
#
# ---------------Random Forest------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        58
#            1       0.96      0.96      0.96        85
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# ---------------AdaBoost------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        58
#            1       0.95      0.96      0.96        85
#
# ...

# %%
plt.figure(figsize=(12,5))

plot_tree(model_dt,
          filled=True,
          rounded=True)

plt.show()
