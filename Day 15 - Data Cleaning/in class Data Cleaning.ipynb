# %%
data = [
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 120000, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 120000, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 120000, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1002, "Customer Name": "Bob Jones", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-16", "Delivery Status": True},
    {"Transaction ID": 1003, "Customer Name": "Charlie Johnson", "Email": "charlie#example.com", "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "16/09/2024", "Delivery Status": True},
    {"Transaction ID": 1004, "Customer Name": "David Lee", "Email": "david.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-17", "Delivery Status": False},
    {"Transaction ID": 1005, "Customer Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3, "Price": None, "Purchase Date": "17th Sep 2024", "Delivery Status": True},
    {"Transaction ID": 1006, "Customer Name": "Frank Wright", "Email": None, "Product": "Tablet", "Quantity": None, "Price": 600.00, "Purchase Date": "2024-09-18", "Delivery Status": False},
    {"Transaction ID": 1007, "Customer Name": "Grace Lee", "Email": "grace.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-19", "Delivery Status": True},
    {"Transaction ID": 1008, "Customer Name": "Hank Brown", "Email": "hank.brown@example.com", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/19/2024", "Delivery Status": True},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1010, "Customer Name": "Jack Davis", "Email": None, "Product": "Mouse", "Quantity": 5, "Price": 50.00, "Purchase Date": "2024-09-21", "Delivery Status": True},
    {"Transaction ID": 1011, "Customer Name": "Alice Smith", "Email": None, "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},  # Duplicate entry
    {"Transaction ID": 1012, "Customer Name": "Kurt Evans", "Email": "kurt.evans@example.com", "Product": "Smartwatch", "Quantity": -1, "Price": 200.00, "Purchase Date": "2024-09-22", "Delivery Status": True},  # Outlier quantity
    {"Transaction ID": 1013, "Customer Name": "Liam Adams", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-23", "Delivery Status": False},
    {"Transaction ID": 1014, "Customer Name": "Mia Clark", "Email": "mia.clark@example.com", "Product": None, "Quantity": 1, "Price": 0, "Purchase Date": "2024-09-24", "Delivery Status": True},  # Price anomaly
    {"Transaction ID": 1015, "Customer Name": "Nina Turner", "Email": None, "Product": "Tablet", "Quantity": 1, "Price": 600.00, "Purchase Date": "24-09-2024", "Delivery Status": True},
    {"Transaction ID": 1016, "Customer Name": "Oscar Harris", "Email": None, "Product": "Laptop", "Quantity": 2, "Price": 1200.00, "Purchase Date": "2024-09-25", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": None, "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1018, "Customer Name": "Quinn Lopez", "Email": None, "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "2024-09-26", "Delivery Status": False},
    {"Transaction ID": 1019, "Customer Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024-09-27", "Delivery Status": True},
    {"Transaction ID": 1020, "Customer Name": "Steve King", "Email": "steve.king@example.com", "Product": "Mouse", "Quantity": None, "Price": 50.00, "Purchase Date": "2024-09-28", "Delivery Status": True},
]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Transaction ID    Customer Name                Email     Product  Quantity  \
# 0            1001      Alice Smith    alice@example.com      Laptop       1.0
# 1            1001      Alice Smith    alice@example.com      Laptop       1.0
# 2            1001      Alice Smith    alice@example.com      Laptop       1.0
# 3            1002        Bob Jones                 None  Headphones       2.0
# 4            1003  Charlie Johnson  charlie#example.com  Smartphone       1.0
#
#       Price Purchase Date  Delivery Status
# 0  120000.0    2024-09-15             True
# 1  120000.0    2024-09-15             True
# 2  120000.0    2024-09-15             True
# 3     150.0    2024-09-16             True
# 4     800.0    16/09/2024             True

# %%
# try to know our data better

#issues with data

#missing values

# %% [markdown]
# ### Missing Values ###
# - Nan

# %%
learners={
       'names': ['idrees','ibrahim','hazira','mel','aisyah','amin']
   }

x = pd.DataFrame(learners)

# create a new column,state in this 

x['state'] = ['J&K','Selangor','N9','Johor','Selangor','Penang']
# nak create value, mesti cukup dgn indexes 
x['state3'] = {} # dictionary blh emplt, list takleh 
x
# Out:
#      names     state state3
# 0   idrees       J&K    NaN
# 1  ibrahim  Selangor    NaN
# 2   hazira        N9    NaN
# 3      mel     Johor    NaN
# 4   aisyah  Selangor    NaN
# 5     amin    Penang    NaN

# %%
x.head()
# Out:
#      names     state state3
# 0   idrees       J&K    NaN
# 1  ibrahim  Selangor    NaN
# 2   hazira        N9    NaN
# 3      mel     Johor    NaN
# 4   aisyah  Selangor    NaN

# %%
x['state'] = [1,2,3,4,5,6] # nak ganti list mesti cukup dgn apa yg diganti 
x
# Out:
#      names  state state3
# 0   idrees      1    NaN
# 1  ibrahim      2    NaN
# 2   hazira      3    NaN
# 3      mel      4    NaN
# 4   aisyah      5    NaN
# 5     amin      6    NaN

# %%
x['state'] = {0:8,1:1,2:2,3:3,4:4,5:np.nan,6:6} # dict based on index blh tak cukup 
# x['state'] = (1,2,3,4,5,6) # tuple 
x
# Out:
#      names  state state3
# 0   idrees    8.0    NaN
# 1  ibrahim    1.0    NaN
# 2   hazira    2.0    NaN
# 3      mel    3.0    NaN
# 4   aisyah    4.0    NaN
# 5     amin    NaN    NaN

# %%
x1 = x['state3'][5]
x1
# Out:
# nan

# %%
type(x1)
# Out:
# float

# %% [markdown]
# - when there is no value
# - (NaN)
# - empty

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   22 non-null     int64
#  1   Customer Name    22 non-null     object
#  2   Email            12 non-null     object
#  3   Product          21 non-null     object
#  4   Quantity         20 non-null     float64
#  5   Price            21 non-null     float64
#  6   Purchase Date    22 non-null     object
#  7   Delivery Status  22 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.4+ KB

# %%
df.head()
# Out:
#    Transaction ID    Customer Name                Email     Product  Quantity  \
# 0            1001      Alice Smith    alice@example.com      Laptop       1.0
# 1            1001      Alice Smith    alice@example.com      Laptop       1.0
# 2            1001      Alice Smith    alice@example.com      Laptop       1.0
# 3            1002        Bob Jones                 None  Headphones       2.0
# 4            1003  Charlie Johnson  charlie#example.com  Smartphone       1.0
#
#       Price Purchase Date  Delivery Status
# 0  120000.0    2024-09-15             True
# 1  120000.0    2024-09-15             True
# 2  120000.0    2024-09-15             True
# 3     150.0    2024-09-16             True
# 4     800.0    16/09/2024             True

# %%
df.describe() # numerical
# Out:
#        Transaction ID   Quantity          Price
# count       22.000000  20.000000      21.000000
# mean      1009.636364   1.550000   17571.428571
# std          6.283353   1.145931   42851.016824
# min       1001.000000  -1.000000       0.000000
# 25%       1004.250000   1.000000     150.000000
# 50%       1009.500000   1.000000     600.000000
# 75%       1014.750000   2.000000    1200.000000
# max       1020.000000   5.000000  120000.000000

# %%
df.describe(include='all') # values for all columns
# Out:
#         Transaction ID Customer Name              Email Product   Quantity  \
# count        22.000000            22                 12      21  20.000000
# unique             NaN            19                 10       8        NaN
# top                NaN   Alice Smith  alice@example.com  Laptop        NaN
# freq               NaN             4                  3       7        NaN
# mean       1009.636364           NaN                NaN     NaN   1.550000
# std           6.283353           NaN                NaN     NaN   1.145931
# min        1001.000000           NaN                NaN     NaN  -1.000000
# 25%        1004.250000           NaN                NaN     NaN   1.000000
# 50%        1009.500000           NaN                NaN     NaN   1.000000
# 75%        1014.750000           NaN                NaN     NaN   2.000000
# max        1020.000000           NaN                NaN     NaN   5.000000
#
#                 Price Purchase Date Delivery Status
# count       21.000000            22              22
# unique            NaN            19               2
# top               NaN    2024-09-15            True
# freq              NaN             4              17
# mean     17571.428571           NaN             NaN
# std      42851.016824           NaN             NaN
# min          0.000000           NaN             NaN
# 25%        150.000000           NaN             NaN
# 50%        600.000000           NaN             NaN
# 75%       1200.000000           NaN             NaN
# max     120000.000000           NaN             NaN

# %%
df.sample(5) # ambil data randomly
# Out:
#     Transaction ID Customer Name                     Email     Product  \
# 6             1005  Eve Martinez  eve.martinez@example.com  Smartwatch
# 8             1007     Grace Lee     grace.lee@example.com      Laptop
# 15            1014     Mia Clark     mia.clark@example.com        None
# 5             1004     David Lee     david.lee@example.com      Laptop
# 9             1008    Hank Brown    hank.brown@example.com     Monitor
#
#     Quantity   Price  Purchase Date  Delivery Status
# 6        3.0     NaN  17th Sep 2024             True
# 8        1.0  1200.0     2024-09-19             True
# 15       1.0     0.0     2024-09-24             True
# 5        1.0  1200.0     2024-09-17            False
# 9        2.0   300.0     09/19/2024             True

# %%
df.isnull() # retirn false if there is value, vice versa
# Out:
#     Transaction ID  Customer Name  Email  Product  Quantity  Price  \
# 0            False          False  False    False     False  False
# 1            False          False  False    False     False  False
# 2            False          False  False    False     False  False
# 3            False          False   True    False     False  False
# 4            False          False  False    False     False  False
# 5            False          False  False    False     False  False
# 6            False          False  False    False     False   True
# 7            False          False   True    False      True  False
# 8            False          False  False    False     False  False
# 9            False          False  False    False     False  False
# 10           False          False   True    False     False  False
# 11           False          False   True    False     False  False
# 12           False          False   True    False     False  False
# 13           False          False  False    False     False  False
# 14           False          False   True    False     False  False
# 15           False          False  False     True     False  False
# 16           False          False   True    False     False  False
# 17           False          False   True    False     False  False
# 18           False          False   True    False     False  False
# 19           False          False   True    False     False  False
# 20           False          False  False    False     False  False
# 21           False          False  False    False      True  False
#
#     Purchase Date  Delivery Status
# 0           False            False
# 1           False            False
# 2           False            False
# 3           False            False
# 4           False            False
# 5           False            False
# 6           False            False
# 7           False            False
# 8           False            False
# 9           False            False
# 10          False            False
# 11          False            False
# 12          False            False
# 13          False            False
# 14          False            False
# 15          False            False
# 16          False            False
# 17          False            False
# 18          False            False
# 19          False            False
# 20          False            False
# 21          False            False

# %%
countnull = df.isnull().sum() # total berapa true (takde data)
type(countnull)
# Out:
# pandas.core.series.Series

# %%
countnull
# Out:
# Transaction ID      0
# Customer Name       0
# Email              10
# Product             1
# Quantity            2
# Price               1
# Purchase Date       0
# Delivery Status     0
# dtype: int64

# %%
# create a visualisation to see which column has the highest nullvalues
sns.barplot(data=countnull)
plt.xticks(rotation = 45, horizontalalignment='right', fontsize=8)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Transaction ID'),
#   Text(1, 0, 'Customer Name'),
#   Text(2, 0, 'Email'),
#   Text(3, 0, 'Product'),
#   Text(4, 0, 'Quantity'),
#   Text(5, 0, 'Price'),
#   Text(6, 0, 'Purchase Date'),
#   Text(7, 0, 'Delivery Status')])

# %%
countnull.index
# Out:
# Index(['Transaction ID', 'Customer Name', 'Email', 'Product', 'Quantity',
#        'Price', 'Purchase Date', 'Delivery Status'],
#       dtype='object')

# %%
x = countnull.index
y = countnull

plt.xticks(rotation = 45, horizontalalignment='right', fontsize=8)

plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
for i in countnull:
    
    missing = countnull.values
    
    total = len(df)
    
    bar = '|' *int((missing[i])) #simple visualisation
    
    print(f"{countnull.index[i]:15} mising: {bar}") # :15 untuk tambahkan space kasia align
# Out:
# Transaction ID  mising:
# Transaction ID  mising:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 7
#       3 missing = countnull.values
#       5 total = len(df)
# ----> 7 bar = '|' *int((missing[i])) #simple visualisation
#       9 print(f"{countnull.index[i]:15} mising: {bar}") # :15 untuk tambahkan space kasia align
#
# IndexError: index 10 is out of bounds for axis 0 with size 8

# %%
x = 'a'
y = 'b'

x =6.6565656
y=767.565656

print(f'{x:.2f} missing: {y:.5f}')
# Out:
# 6.66 missing: 767.56566

# %% [markdown]
# ###duplicate values ###

# %%
df.duplicated() # check for udplicated rows
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# dtype: bool

# %%
df.duplicated().sum() # check for berapa banyk
# Out:
# np.int64(2)

# %%
df['Customer Name'].duplicated()
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: Customer Name, dtype: bool

# %%
df['Customer Name'].duplicated().sum()
# Out:
# np.int64(3)

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(10)

# %%
df['Price']
# Out:
# 0     120000.0
# 1     120000.0
# 2     120000.0
# 3        150.0
# 4        800.0
# 5       1200.0
# 6          NaN
# 7        600.0
# 8       1200.0
# 9        300.0
# 10       100.0
# 11        50.0
# 12      1200.0
# 13       200.0
# 14       150.0
# 15         0.0
# 16       600.0
# 17      1200.0
# 18       300.0
# 19       800.0
# 20       100.0
# 21        50.0
# Name: Price, dtype: float64

# %%
print(df['Price'].min())
print(df['Price'].max())
# Out:
# 0.0
# 120000.0

# %%
plt.boxplot(df['Quantity'].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e9e4683620>,
#   <matplotlib.lines.Line2D at 0x1e9e4683770>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e9e46838c0>,
#   <matplotlib.lines.Line2D at 0x1e9e4683a10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e9e46834d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e9e4683b60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e9e4683cb0>],
#  'means': []}

# %%
data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 200, 40],  # 200 is an outlier
}
 
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David  200
# 4      Eve   40

# %%
plt.hist(df2['Age'])
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 25. ,  42.5,  60. ,  77.5,  95. , 112.5, 130. , 147.5, 165. ,
#         182.5, 200. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df2['Age']) # use boxplot to check outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e9e486a510>,
#   <matplotlib.lines.Line2D at 0x1e9e486a660>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e9e486a7b0>,
#   <matplotlib.lines.Line2D at 0x1e9e486a900>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e9e486a3c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e9e486aa50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e9e486aba0>],
#  'means': []}

# %% [markdown]
# ## Handling missing values ###

# %%
dfnew=df.copy()

# %%
dfnew['Price'][0]=800

dfnew.dropna(inplace=True) #  || dfnewwithoutnull = dfnew.dropna()
#inplace means do it on the dataframe
#dfnewwithoutnull

dfnew.isnull().sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15660\465662747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['Price'][0]=800
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew.info() # untuk tengok data yg didrop
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   9 non-null      int64
#  1   Customer Name    9 non-null      object
#  2   Email            9 non-null      object
#  3   Product          9 non-null      object
#  4   Quantity         9 non-null      float64
#  5   Price            9 non-null      float64
#  6   Purchase Date    9 non-null      object
#  7   Delivery Status  9 non-null      bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 585.0+ bytes

# %%
plt.boxplot(dfnew['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e9e4aa1400>,
#   <matplotlib.lines.Line2D at 0x1e9e4aa1550>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e9e4aa16a0>,
#   <matplotlib.lines.Line2D at 0x1e9e4aa17f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e9e4aa12b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e9e4aa1940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e9e4aa1a90>],
#  'means': []}

# %%
dfnew = df.copy()
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1002        Bob Jones                      None  Headphones
# 4             1003  Charlie Johnson       charlie#example.com  Smartphone
# 5             1004        David Lee     david.lee@example.com      Laptop
# 6             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 7             1006     Frank Wright                      None      Tablet
# 8             1007        Grace Lee     grace.lee@example.com      Laptop
# 9             1008       Hank Brown    hank.brown@example.com     Monitor
# 10            1009     Ivy Thompson                      None    Keyboard
# 11            1010       Jack Davis                      None       Mouse
# 12            1011      Alice Smith                      None      Laptop
# 13            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 14            1013       Liam Adams                      None  Headphones
# 15            1014        Mia Clark     mia.clark@example.com        None
# 16            1015      Nina Turner                      None      Tablet
# 17            1016     Oscar Harris                      None      Laptop
# 18            1017       Paul Young                      None     Monitor
# 19            1018      Quinn Lopez                      None  Smartphone
# 20            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 21            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity     Price  Purchase Date  Delivery Status
# 0        1.0  120000.0     2024-09-15             True
# 1        1.0  120000.0     2024-09-15             True
# 2        1.0  120000.0     2024-09-15             True
# 3        2.0     150.0     2024-09-16             True
# 4        1.0     800.0     16/09/2024             True
# 5        1.0    1200.0     2024-09-17            False
# 6        3.0       NaN  17th Sep 2024             True
# 7        NaN     600.0     2024-09-18            False
# 8        1.0    1200.0     2024-09-19             True
# 9        2.0     300.0     09/19/2024             True
# 10       2.0     100.0     2024/09/20            False
# 11       5.0      50.0     2024-09-21             True
# 12       1.0    1200.0     2024-09-15             True
# 13      -1.0     200.0     2024-09-22             True
# 14       2.0     150.0     2024-09-23            False
# 15       1.0       0.0     2024-09-24             True
# 16       1.0     600.0     24-09-2024             True
# 17       2.0    1200.0     2024-09-25             True
# 18       2.0     300.0     09/25/2024             True
# 19       1.0     800.0     2024-09-26            False
# 20       2.0     100.0     2024-09-27             True
# 21       NaN      50.0     2024-09-28             True

# %%
dfnew.isnull().sum()
# Out:
# Transaction ID      0
# Customer Name       0
# Email              10
# Product             1
# Quantity            2
# Price               1
# Purchase Date       0
# Delivery Status     0
# dtype: int64

# %%
dfnew.dropna(inplace=True,subset=['Quantity','Price','Product']) #  make quantity,price,product the base

dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1002        Bob Jones                      None  Headphones
# 4             1003  Charlie Johnson       charlie#example.com  Smartphone
# 5             1004        David Lee     david.lee@example.com      Laptop
# 8             1007        Grace Lee     grace.lee@example.com      Laptop
# 9             1008       Hank Brown    hank.brown@example.com     Monitor
# 10            1009     Ivy Thompson                      None    Keyboard
# 11            1010       Jack Davis                      None       Mouse
# 12            1011      Alice Smith                      None      Laptop
# 13            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 14            1013       Liam Adams                      None  Headphones
# 16            1015      Nina Turner                      None      Tablet
# 17            1016     Oscar Harris                      None      Laptop
# 18            1017       Paul Young                      None     Monitor
# 19            1018      Quinn Lopez                      None  Smartphone
# 20            1019     Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity     Price Purchase Date  Delivery Status
# 0        1.0  120000.0    2024-09-15             True
# 1        1.0  120000.0    2024-09-15             True
# 2        1.0  120000.0    2024-09-15             True
# 3        2.0     150.0    2024-09-16             True
# 4        1.0     800.0    16/09/2024             True
# 5        1.0    1200.0    2024-09-17            False
# 8        1.0    1200.0    2024-09-19             True
# 9        2.0     300.0    09/19/2024             True
# 10       2.0     100.0    2024/09/20            False
# 11       5.0      50.0    2024-09-21             True
# 12       1.0    1200.0    2024-09-15             True
# 13      -1.0     200.0    2024-09-22             True
# 14       2.0     150.0    2024-09-23            False
# 16       1.0     600.0    24-09-2024             True
# 17       2.0    1200.0    2024-09-25             True
# 18       2.0     300.0    09/25/2024             True
# 19       1.0     800.0    2024-09-26            False
# 20       2.0     100.0    2024-09-27             True

# %%
dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              9
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %% [markdown]
# ### Filling the values ###

# %%
newdf = df.copy()
newdf.isnull().sum()
# Out:
# Transaction ID      0
# Customer Name       0
# Email              10
# Product             1
# Quantity            2
# Price               1
# Purchase Date       0
# Delivery Status     0
# dtype: int64

# %%
newdf['Price'].fillna(0,inplace=True) # if nak tukar to zero

# %%
# we are using central tendency to fill the nan values
newdf = df.copy()

median_price = dfnew['Price'].median().round(2)
print(median_price)

newdf['Price'].fillna(median_price,inplace=True)
# Out:
# 700.0

# %%
median_quantity = dfnew['Quantity'].median().round(2)
print(median_quantity) # median lagi better as value ssebb not affected by outlier

newdf['Quantity'].fillna(median_quantity,inplace=True)
newdf['Quantity'].fillna(median_quantity,inplace=True)
newdf
# Out:
# 1.5
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1002        Bob Jones                      None  Headphones
# 4             1003  Charlie Johnson       charlie#example.com  Smartphone
# 5             1004        David Lee     david.lee@example.com      Laptop
# 6             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 7             1006     Frank Wright                      None      Tablet
# 8             1007        Grace Lee     grace.lee@example.com      Laptop
# 9             1008       Hank Brown    hank.brown@example.com     Monitor
# 10            1009     Ivy Thompson                      None    Keyboard
# 11            1010       Jack Davis                      None       Mouse
# 12            1011      Alice Smith                      None      Laptop
# 13            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 14            1013       Liam Adams                      None  Headphones
# 15            1014        Mia Clark     mia.clark@example.com        None
# 16            1015      Nina Turner                      None      Tablet
# 17            1016     Oscar Harris                      None      Laptop
# 18            1017       Paul Young                      None     Monitor
# 19            1018      Quinn Lopez                      None  Smartphone
# 20            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 21            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity      Price  Purchase Date  Delivery Status
# 0        1.0  120000.00     2024-09-15             True
# 1        1.0  120000.00     2024-09-15             True
# 2        1.0  120000.00     2024-09-15             True
# 3        2.0     150.00     2024-09-16             True
# 4        1.0     800.00     16/09/2024             True
# 5        1.0    1200.00     2024-09-17            False
# 6        3.0   20463.89  17th Sep 2024             True
# 7        1.5     600.00     2024-09-18            False
# 8        1.0    1200.00     2024-09-19             True
# 9        2.0     300.00     09/19/2024             True
# 10       2.0     100.00     2024/09/20            False
# 11       5.0      50.00     2024-09-21             True
# 12       1.0    1200.00     2024-09-15             True
# 13       1.5     200.00     2024-09-22             True
# 14       2.0     150.00     2024-09-23            False
# 15       1.0       0.00     2024-09-24             True
# 16       1.0     600.00     24-09-2024             True
# 17       2.0    1200.00     2024-09-25             True
# 18       2.0     300.00     09/25/2024             True
# 19       1.0     800.00     2024-09-26            False
# 20       2.0     100.00     2024-09-27             True
# 21       1.5      50.00     2024-09-28             True

# %%
print(newdf['Price'].sort_values())
# Out:
# 15         0.0
# 11        50.0
# 21        50.0
# 10       100.0
# 20       100.0
# 3        150.0
# 14       150.0
# 13       200.0
# 9        300.0
# 18       300.0
# 16       600.0
# 7        600.0
# 6        700.0
# 4        800.0
# 19       800.0
# 8       1200.0
# 5       1200.0
# 17      1200.0
# 12      1200.0
# 1     120000.0
# 0     120000.0
# 2     120000.0
# Name: Price, dtype: float64

# %%
squared = newdf['Quantity'] **2 # square everything
newQuantity = squared / (squared**0.5) # divide their squares with their roots
newQuantity

newdf['Quantity'] = newQuantity
newdf

median_qnty = newdf['Quantity'].median()
newdf['Quantity'].fillna(median_qnty,inplace= True)
newdf
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1002        Bob Jones                      None  Headphones
# 4             1003  Charlie Johnson       charlie#example.com  Smartphone
# 5             1004        David Lee     david.lee@example.com      Laptop
# 6             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 7             1006     Frank Wright                      None      Tablet
# 8             1007        Grace Lee     grace.lee@example.com      Laptop
# 9             1008       Hank Brown    hank.brown@example.com     Monitor
# 10            1009     Ivy Thompson                      None    Keyboard
# 11            1010       Jack Davis                      None       Mouse
# 12            1011      Alice Smith                      None      Laptop
# 13            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 14            1013       Liam Adams                      None  Headphones
# 15            1014        Mia Clark     mia.clark@example.com        None
# 16            1015      Nina Turner                      None      Tablet
# 17            1016     Oscar Harris                      None      Laptop
# 18            1017       Paul Young                      None     Monitor
# 19            1018      Quinn Lopez                      None  Smartphone
# 20            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 21            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity     Price  Purchase Date  Delivery Status
# 0        1.0  120000.0     2024-09-15             True
# 1        1.0  120000.0     2024-09-15             True
# 2        1.0  120000.0     2024-09-15             True
# 3        2.0     150.0     2024-09-16             True
# 4        1.0     800.0     16/09/2024             True
# 5        1.0    1200.0     2024-09-17            False
# 6        3.0     700.0  17th Sep 2024             True
# 7        1.0     600.0     2024-09-18            False
# 8        1.0    1200.0     2024-09-19             True
# 9        2.0     300.0     09/19/2024             True
# 10       2.0     100.0     2024/09/20            False
# 11       5.0      50.0     2024-09-21             True
# 12       1.0    1200.0     2024-09-15             True
# 13       1.0     200.0     2024-09-22             True
# 14       2.0     150.0     2024-09-23            False
# 15       1.0       0.0     2024-09-24             True
# 16       1.0     600.0     24-09-2024             True
# 17       2.0    1200.0     2024-09-25             True
# 18       2.0     300.0     09/25/2024             True
# 19       1.0     800.0     2024-09-26            False
# 20       2.0     100.0     2024-09-27             True
# 21       1.0      50.0     2024-09-28             True

# %%
newdf['Price'].quantile(0.5) # sama dgn median
# Out:
# np.float64(600.0)

# %%
newdf['Price'].quantile(1)
# Out:
# np.float64(120000.0)

# %%
Q1=newdf['Price'].quantile(0.25)
Q3=newdf['Price'].quantile(0.75)
IQR_prices = Q3 - Q1
IQR_prices # the range
# Out:
# np.float64(1050.0)

# %% [markdown]
# # df - no outliers, no missing values,no duplicates,
#
# # steps can be changed depends on the ...
# 1. check for duplicates and remove duplicates
# 2. check for missing values,
#         3. remove nan
#         - OR
# 4. check and remove outliers
# if x nak remove blh impute
# - impute them - filling the values
